# %% [markdown]
# COMP 215 - LAB 2 (NEO)
# ----------------
# #### Name:
# #### Date:
#
# This lab exercise is mostly a review of strings, tuples, lists, dictionaries, and functions.
#
# **Building on new concepts from lab 1**:
#   * `datetime.date` objects represent a calendar date
#   * *list comprehension* provides a compact way to represent map and filter algorithms
#
# **New Python Concepts**:
#   * *f-string* simplifies string formatting operations
#
# As usual, the first code cell simply imports all the modules we'll be using...

# %%
import datetime, json, requests
from pprint import pprint    # Pretty Print - built-in python function to nicely format data structures

# %% [markdown]
# We'll answer some questions about [Near Earth Objects](https://cneos.jpl.nasa.gov/)
# > using NASA's API:  [https://api.nasa.gov/](https://api.nasa.gov/#NeoWS)
#
# You should register for your own API key, (but may use the DEMO_KEY to get started).
#
# First we need a short tutorial on python dates and [f-strings](https://realpython.com/python-f-strings/)...

# %%
today = datetime.date.today()   # get a date object representing today's date
print(today, type(today))
formatted_date = f'Today is: {today}'   # A format string - notice how the variable `today` is formatted into the stringg
print(formatted_date)
# Out:
# 2023-03-08 <class 'datetime.date'>
# Today is: 2023-03-08

# %% [markdown]
# ### Make a query
#
# Let's get some data from the NEO database...
# Here's a query that gets the observation "feed" for today.
# (Note: I hard-coded the date below to lock down the data for the lab - ideally used `today()` so the notebook is always up-to-date.)

# %%
API_KEY = 'DEMO_KEY'  # substitute your API key here

today = '2023-01-09'  #  Future enhancement:  str(datetime.date.today())   # Today's date as a string!
# Use an f-string here to "format" the date and API key varaibles.
url = f'https://api.nasa.gov/neo/rest/v1/feed?start_date={today}&end_date={today}&api_key={API_KEY}'

response = requests.request("GET", url, headers={}, data={})

data = json.loads(response.text)  # recall json.loads for lab 1

# TIP: print(data) to see the whole data structure returned, here we grab just the list of NEO's:
n_results = data['element_count']
neos = data['near_earth_objects'][today]
print(f'{n_results} Near Earth Objects found for {today}')
pprint(neos)
# Out:
# 12 Near Earth Objects found for 2023-01-09
# [{'absolute_magnitude_h': 19.64,
#   'close_approach_data': [{'close_approach_date': '2023-01-09',
#                            'close_approach_date_full': '2023-Jan-09 13:59',
#                            'epoch_date_close_approach': 1673272740000,
#                            'miss_distance': {'astronomical': '0.0725378004',
#                                              'kilometers': '10851500.434325148',
#                                              'lunar': '28.2172043556',
#                                              'miles': '6742809.7016491224'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '32387.333793389',
#                                                  'kilometers_per_second': '8.9964816093',
#                                                  'miles_per_hour': '20124.2297117866'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 2301.5744618737,
#                                   'estimated_diameter_min': 1029.2953904054},
#                          'kilometers': {'estimated_diameter_max': 0.7015198735,
#                                         'estimated_diameter_min': 0.313729225},
#                          'meters': {'estimated_diameter_max': 701.5198735305,
#                                     'estimated_diameter_min': 313.7292249562},
#                          'miles': {'estimated_diameter_max': 0.4359041053,
#                                    'estimated_diameter_min': 0.1949422422}},
#   'id': '2226554',
#   'is_potentially_hazardous_asteroid': True,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2226554?api_key=DEMO_KEY'},
#   'name': '226554 (2003 WR21)',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2226554',
#   'neo_reference_id': '2226554'},
#  {'absolute_magnitude_h': 20.64,
#   'close_approach_data': [{'close_approach_date': '2023-01-09',
#                            'close_approach_date_full': '2023-Jan-09 16:33',
#                            'epoch_date_close_approach': 1673281980000,
#                            'miss_distance': {'astronomical': '0.288478006',
#                                              'kilometers': '43155695.23944722',
#                                              'lunar': '112.217944334',
#                                              'miles': '26815705.561002836'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '30014.4374944811',
#                                                  'kilometers_per_second': '8.3373437485',
#                                                  'miles_per_hour': '18649.8042309458'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 1452.1953105872,
#                                   'estimated_diameter_min': 649.4414862159},
#                          'kilometers': {'estimated_diameter_max': 0.4426291165,
#                                         'estimated_diameter_min': 0.1979497587},
#                          'meters': {'estimated_diameter_max': 442.6291165029,
#                                     'estimated_diameter_min': 197.9497586642},
#                          'miles': {'estimated_diameter_max': 0.2750368968,
#                                    'estimated_diameter_min': 0.1230002395}},
#   'id': '2307070',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2307070?api_key=DEMO_KEY'},
#   'name': '307070 (2002 AV31)',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2307070',
#   'neo_reference_id': '2307070'},
#  {'absolute_magnitude_h': 18.39,
#   'close_approach_data': [{'close_approach_date': '2023-01-09',
#                            'close_approach_date_full': '2023-Jan-09 01:00',
#                            'epoch_date_close_approach': 1673226000000,
#                            'miss_distance': {'astronomical': '0.3628966736',
#                                              'kilometers': '54288569.400645232',
#                                              'lunar': '141.1668060304',
#                                              'miles': '33733352.7892069216'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '88002.0997277573',
#                                                  'kilometers_per_second': '24.4450277022',
#                                                  'miles_per_hour': '54681.0824669501'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 4092.8424762213,
#                                   'estimated_diameter_min': 1830.3747996059},
#                          'kilometers': {'estimated_diameter_max': 1.2474983468,
#                                         'estimated_diameter_min': 0.5578982211},
#                          'meters': {'estimated_diameter_max': 1247.4983468323,
#                                     'estimated_diameter_min': 557.8982210671},
#                          'miles': {'estimated_diameter_max': 0.7751592953,
#                                    'estimated_diameter_min': 0.3466617755}},
#   'id': '2436325',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2436325?api_key=DEMO_KEY'},
#   'name': '436325 (2010 GR7)',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2436325',
#   'neo_reference_id': '2436325'},
#  {'absolute_magnitude_h': 20.94,
#   'close_approach_data': [{'close_approach_date': '2023-01-09',
#                            'close_approach_date_full': '2023-Jan-09 03:25',
#                            'epoch_date_close_approach': 1673234700000,
#                            'miss_distance': {'astronomical': '0.1211166399',
#                                              'kilometers': '18118791.350597013',
#                                              'lunar': '47.1143729211',
#                                              'miles': '11258494.8819162594'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '22658.3665761987',
#                                                  'kilometers_per_second': '6.2939907156',
#                                                  'miles_per_hour': '14079.0278317497'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 1264.8092410264,
#                                   'estimated_diameter_min': 565.639888301},
#                          'kilometers': {'estimated_diameter_max': 0.3855138443,
#                                         'estimated_diameter_min': 0.1724070324},
#                          'meters': {'estimated_diameter_max': 385.5138443284,
#                                     'estimated_diameter_min': 172.4070324371},
#                          'miles': {'estimated_diameter_max': 0.239547123,
#                                    'estimated_diameter_min': 0.1071287302}},
#   'id': '2508908',
#   'is_potentially_hazardous_asteroid': True,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2508908?api_key=DEMO_KEY'},
#   'name': '508908 (2003 YX1)',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2508908',
#   'neo_reference_id': '2508908'},
#  {'absolute_magnitude_h': 21.3,
#   'close_approach_data': [{'close_approach_date': '2023-01-09',
#                            'close_approach_date_full': '2023-Jan-09 07:10',
#                            'epoch_date_close_approach': 1673248200000,
#                            'miss_distance': {'astronomical': '0.4928732055',
#                                              'kilometers': '73732781.722872285',
#                                              'lunar': '191.7276769395',
#                                              'miles': '45815426.073056133'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '121198.8588141982',
#                                                  'kilometers_per_second': '33.6663496706',
#                                                  'miles_per_hour': '75308.2575781889'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 1071.581062656,
#                                   'estimated_diameter_min': 479.2256199},
#                          'kilometers': {'estimated_diameter_max': 0.3266178974,
#                                         'estimated_diameter_min': 0.1460679643},
#                          'meters': {'estimated_diameter_max': 326.6178974458,
#                                     'estimated_diameter_min': 146.0679642714},
#                          'miles': {'estimated_diameter_max': 0.2029508896,
#                                    'estimated_diameter_min': 0.090762397}},
#   'id': '3014110',
#   'is_potentially_hazardous_asteroid': True,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3014110?api_key=DEMO_KEY'},
#   'name': '(1998 SU4)',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3014110',
#   'neo_reference_id': '3014110'},
#  {'absolute_magnitude_h': 25.2,
#   'close_approach_data': [{'close_approach_date': '2023-01-09',
#                            'close_approach_date_full': '2023-Jan-09 23:16',
#                            'epoch_date_close_approach': 1673306160000,
#                            'miss_distance': {'astronomical': '0.0850918493',
#                                              'kilometers': '12729559.409640991',
#                                              'lunar': '33.1007293777',
#                                              'miles': '7909781.4357120358'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '36346.1238024887',
#                                                  'kilometers_per_second': '10.0961455007',
#                                                  'miles_per_hour': '22584.0678704964'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 177.8381901842,
#                                   'estimated_diameter_min': 79.5316564495},
#                          'kilometers': {'estimated_diameter_max': 0.0542050786,
#                                         'estimated_diameter_min': 0.0242412481},
#                          'meters': {'estimated_diameter_max': 54.2050786336,
#                                     'estimated_diameter_min': 24.2412481101},
#                          'miles': {'estimated_diameter_max': 0.0336814639,
#                                    'estimated_diameter_min': 0.0150628086}},
#   'id': '3559843',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3559843?api_key=DEMO_KEY'},
#   'name': '(2011 EP51)',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3559843',
#   'neo_reference_id': '3559843'},
#  {'absolute_magnitude_h': 26.9,
#   'close_approach_data': [{'close_approach_date': '2023-01-09',
#                            'close_approach_date_full': '2023-Jan-09 14:16',
#                            'epoch_date_close_approach': 1673273760000,
#                            'miss_distance': {'astronomical': '0.4272893529',
#                                              'kilometers': '63921577.067518323',
#                                              'lunar': '166.2155582781',
#                                              'miles': '39719026.1940379374'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '16576.4865892554',
#                                                  'kilometers_per_second': '4.6045796081',
#                                                  'miles_per_hour': '10299.9841254181'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 81.2877363957,
#                                   'estimated_diameter_min': 36.3529808636},
#                          'kilometers': {'estimated_diameter_max': 0.0247765013,
#                                         'estimated_diameter_min': 0.0110803882},
#                          'meters': {'estimated_diameter_max': 24.7765012606,
#                                     'estimated_diameter_min': 11.0803882126},
#                          'miles': {'estimated_diameter_max': 0.0153953994,
#                                    'estimated_diameter_min': 0.0068850319}},
#   'id': '3789481',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3789481?api_key=DEMO_KEY'},
#   'name': '(2017 WU1)',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3789481',
#   'neo_reference_id': '3789481'},
#  {'absolute_magnitude_h': 25.4,
#   'close_approach_data': [{'close_approach_date': '2023-01-09',
#                            'close_approach_date_full': '2023-Jan-09 04:18',
#                            'epoch_date_close_approach': 1673237880000,
#                            'miss_distance': {'astronomical': '0.4741066959',
#                                              'kilometers': '70925351.859377733',
#                                              'lunar': '184.4275047051',
#                                              'miles': '44070970.0473813954'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '71419.4248076035',
#                                                  'kilometers_per_second': '19.8387291132',
#                                                  'miles_per_hour': '44377.253153369'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 162.1903570994,
#                                   'estimated_diameter_min': 72.5337327539},
#                          'kilometers': {'estimated_diameter_max': 0.0494356193,
#                                         'estimated_diameter_min': 0.022108281},
#                          'meters': {'estimated_diameter_max': 49.435619262,
#                                     'estimated_diameter_min': 22.1082810359},
#                          'miles': {'estimated_diameter_max': 0.0307178602,
#                                    'estimated_diameter_min': 0.0137374447}},
#   'id': '54054562',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54054562?api_key=DEMO_KEY'},
#   'name': '(2020 SA3)',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54054562',
#   'neo_reference_id': '54054562'},
#  {'absolute_magnitude_h': 26.1,
#   'close_approach_data': [{'close_approach_date': '2023-01-09',
#                            'close_approach_date_full': '2023-Jan-09 14:29',
#                            'epoch_date_close_approach': 1673274540000,
#                            'miss_distance': {'astronomical': '0.3334722534',
#                                              'kilometers': '49886738.812740258',
#                                              'lunar': '129.7207065726',
#                                              'miles': '30998182.0934332404'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '60765.8145388754',
#                                                  'kilometers_per_second': '16.8793929275',
#                                                  'miles_per_hour': '37757.5140394474'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 117.4965270602,
#                                   'estimated_diameter_min': 52.5460443254},
#                          'kilometers': {'estimated_diameter_max': 0.0358129403,
#                                         'estimated_diameter_min': 0.0160160338},
#                          'meters': {'estimated_diameter_max': 35.8129403019,
#                                     'estimated_diameter_min': 16.0160337979},
#                          'miles': {'estimated_diameter_max': 0.0222531225,
#                                    'estimated_diameter_min': 0.0099518989}},
#   'id': '54104276',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54104276?api_key=DEMO_KEY'},
#   'name': '(2021 AA1)',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54104276',
#   'neo_reference_id': '54104276'},
#  {'absolute_magnitude_h': 27.2,
#   'close_approach_data': [{'close_approach_date': '2023-01-09',
#                            'close_approach_date_full': '2023-Jan-09 14:50',
#                            'epoch_date_close_approach': 1673275800000,
#                            'miss_distance': {'astronomical': '0.1503150963',
#                                              'kilometers': '22486818.235324881',
#                                              'lunar': '58.4725724607',
#                                              'miles': '13972660.9305341178'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '33590.9419665386',
#                                                  'kilometers_per_second': '9.3308172129',
#                                                  'miles_per_hour': '20872.1050235973'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 70.7986587106,
#                                   'estimated_diameter_min': 31.6621227185},
#                          'kilometers': {'estimated_diameter_max': 0.0215794305,
#                                         'estimated_diameter_min': 0.0096506147},
#                          'meters': {'estimated_diameter_max': 21.5794304844,
#                                     'estimated_diameter_min': 9.6506146958},
#                          'miles': {'estimated_diameter_max': 0.0134088323,
#                                    'estimated_diameter_min': 0.0059966121}},
#   'id': '54130489',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54130489?api_key=DEMO_KEY'},
#   'name': '(2021 EP1)',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54130489',
#   'neo_reference_id': '54130489'},
#  {'absolute_magnitude_h': 23.39,
#   'close_approach_data': [{'close_approach_date': '2023-01-09',
#                            'close_approach_date_full': '2023-Jan-09 23:18',
#                            'epoch_date_close_approach': 1673306280000,
#                            'miss_distance': {'astronomical': '0.1990572251',
#                                              'kilometers': '29778536.883070537',
#                                              'lunar': '77.4332605639',
#                                              'miles': '18503524.7992939306'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '42454.2341018916',
#                                                  'kilometers_per_second': '11.7928428061',
#                                                  'miles_per_hour': '26379.4100729226'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 409.2842476221,
#                                   'estimated_diameter_min': 183.0374799606},
#                          'kilometers': {'estimated_diameter_max': 0.1247498347,
#                                         'estimated_diameter_min': 0.0557898221},
#                          'meters': {'estimated_diameter_max': 124.7498346832,
#                                     'estimated_diameter_min': 55.7898221067},
#                          'miles': {'estimated_diameter_max': 0.0775159295,
#                                    'estimated_diameter_min': 0.0346661776}},
#   'id': '54174525',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54174525?api_key=DEMO_KEY'},
#   'name': '(2021 OZ)',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54174525',
#   'neo_reference_id': '54174525'},
#  {'absolute_magnitude_h': 23.52,
#   'close_approach_data': [{'close_approach_date': '2023-01-09',
#                            'close_approach_date_full': '2023-Jan-09 05:43',
#                            'epoch_date_close_approach': 1673242980000,
#                            'miss_distance': {'astronomical': '0.0364123547',
#                                              'kilometers': '5447210.704804489',
#                                              'lunar': '14.1644059783',
#                                              'miles': '3384739.7794963882'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '30422.2576098078',
#                                                  'kilometers_per_second': '8.4506271138',
#                                                  'miles_per_hour': '18903.2077909387'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 385.500574856,
#                                   'estimated_diameter_min': 172.4010981486},
#                          'kilometers': {'estimated_diameter_max': 0.1175005715,
#                                         'estimated_diameter_min': 0.052547853},
#                          'meters': {'estimated_diameter_max': 117.5005714561,
#                                     'estimated_diameter_min': 52.5478530342},
#                          'miles': {'estimated_diameter_max': 0.0730114476,
#                                    'estimated_diameter_min': 0.032651712}},
#   'id': '54201812',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54201812?api_key=DEMO_KEY'},
#   'name': '(2021 TL)',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54201812',
#   'neo_reference_id': '54201812'}]

# %% [markdown]
# Next we extract just the potentially hazerdous asteroids, using a Comp115-style list accumulator *loop*:

# %%
hazards =  []
for item in neos:
  if item['is_potentially_hazardous_asteroid'] is True:
    hazards.append(item)
print(f'{len(hazards)} potentially hazardous asteroids identified.')
# Out:
# 3 potentially hazardous asteroids identified.

# %% [markdown]
# ## Exercise 1
#
# In the code cell below, **re-write the accumulator loop above** as a [list comprehension](https://realpython.com/lessons/list-comprehensions-overview/) that implements a ["filter"](https://youtu.be/hUes6y2b--0)
# Notice how this provides a concise way to "filter" items of interest from a larger data set.

# %%
hazards = [item for item in neos if item['is_potentially_hazardous_asteroid'] == True]

# %% [markdown]
# ## Fetch Complete Data for One Asteroid
#
# Notice that the record for each `neo` is a dictionary with `id` field that uniquely identifies this record in the database.
#
# We can use this `id` to fetch complete orbital and close approach data for the NEO.
#
# For example, this query fetches the complete data set for the first hazardous asteroid...

# %%
id = hazards[0]['id']
url = f'https://api.nasa.gov/neo/rest/v1/neo/{id}/?api_key={API_KEY}'
response = requests.request("GET", url, headers={}, data={})
data = json.loads(response.text)

pprint(data)
# Out:
# {'absolute_magnitude_h': 19.64,
#  'close_approach_data': [{'close_approach_date': '1900-10-30',
#                           'close_approach_date_full': '1900-Oct-30 21:14',
#                           'epoch_date_close_approach': -2182819560000,
#                           'miss_distance': {'astronomical': '0.4183489499',
#                                             'kilometers': '62584111.821776713',
#                                             'lunar': '162.7377415111',
#                                             'miles': '38887963.8272081194'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '30027.9636073959',
#                                                 'kilometers_per_second': '8.3411010021',
#                                                 'miles_per_hour': '18658.2088314955'}},
#                          {'close_approach_date': '1901-06-26',
#                           'close_approach_date_full': '1901-Jun-26 20:27',
#                           'epoch_date_close_approach': -2162172780000,
#                           'miss_distance': {'astronomical': '0.0308797786',
#                                             'kilometers': '4619549.104631582',
#                                             'lunar': '12.0122338754',
#                                             'miles': '2870454.7088645516'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '33429.0353295933',
#                                                 'kilometers_per_second': '9.2858431471',
#                                                 'miles_per_hour': '20771.5025357687'}},
#                          {'close_approach_date': '1907-01-08',
#                           'close_approach_date_full': '1907-Jan-08 04:37',
#                           'epoch_date_close_approach': -1987528980000,
#                           'miss_distance': {'astronomical': '0.1240282192',
#                                             'kilometers': '18554357.412213104',
#                                             'lunar': '48.2469772688',
#                                             'miles': '11529143.0824806752'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '24041.8513295921',
#                                                 'kilometers_per_second': '6.678292036',
#                                                 'miles_per_hour': '14938.6714553235'}},
#                          {'close_approach_date': '1907-09-06',
#                           'close_approach_date_full': '1907-Sep-06 10:51',
#                           'epoch_date_close_approach': -1966684140000,
#                           'miss_distance': {'astronomical': '0.4147265945',
#                                             'kilometers': '62042215.169553715',
#                                             'lunar': '161.3286452605',
#                                             'miles': '38551244.861382667'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '26520.196498121',
#                                                 'kilometers_per_second': '7.3667212495',
#                                                 'miles_per_hour': '16478.6187629575'}},
#                          {'close_approach_date': '1909-08-06',
#                           'close_approach_date_full': '1909-Aug-06 06:41',
#                           'epoch_date_close_approach': -1906219140000,
#                           'miss_distance': {'astronomical': '0.1317214551',
#                                             'kilometers': '19705249.116260637',
#                                             'lunar': '51.2396460339',
#                                             'miles': '12244274.0263133106'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '7812.3388956207',
#                                                 'kilometers_per_second': '2.1700941377',
#                                                 'miles_per_hour': '4854.2835765594'}},
#                          {'close_approach_date': '1912-12-22',
#                           'close_approach_date_full': '1912-Dec-22 20:01',
#                           'epoch_date_close_approach': -1799553540000,
#                           'miss_distance': {'astronomical': '0.4621503265',
#                                             'kilometers': '69136704.464204555',
#                                             'lunar': '179.7764770085',
#                                             'miles': '42959556.092970659'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '78889.9586775109',
#                                                 'kilometers_per_second': '21.9138774104',
#                                                 'miles_per_hour': '49019.1523793678'}},
#                          {'close_approach_date': '1913-10-29',
#                           'close_approach_date_full': '1913-Oct-29 19:08',
#                           'epoch_date_close_approach': -1772686320000,
#                           'miss_distance': {'astronomical': '0.4230475594',
#                                             'kilometers': '63287013.794938478',
#                                             'lunar': '164.5655006066',
#                                             'miles': '39324726.8603598764'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '30216.196529819',
#                                                 'kilometers_per_second': '8.3933879249',
#                                                 'miles_per_hour': '18775.16944932'}},
#                          {'close_approach_date': '1914-06-28',
#                           'close_approach_date_full': '1914-Jun-28 14:48',
#                           'epoch_date_close_approach': -1751793120000,
#                           'miss_distance': {'astronomical': '0.0438429905',
#                                             'kilometers': '6558817.993230235',
#                                             'lunar': '17.0549233045',
#                                             'miles': '4075460.519377843'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '35203.0564564102',
#                                                 'kilometers_per_second': '9.7786267934',
#                                                 'miles_per_hour': '21873.8102742622'}},
#                          {'close_approach_date': '1919-12-30',
#                           'close_approach_date_full': '1919-Dec-30 11:27',
#                           'epoch_date_close_approach': -1578054780000,
#                           'miss_distance': {'astronomical': '0.1880337698',
#                                             'kilometers': '28129451.450150326',
#                                             'lunar': '73.1451364522',
#                                             'miles': '17478830.6269774588'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '22319.465398123',
#                                                 'kilometers_per_second': '6.1998514995',
#                                                 'miles_per_hour': '13868.4478191837'}},
#                          {'close_approach_date': '1920-02-20',
#                           'close_approach_date_full': '1920-Feb-20 02:14',
#                           'epoch_date_close_approach': -1573595160000,
#                           'miss_distance': {'astronomical': '0.2016995784',
#                                             'kilometers': '30173827.308538008',
#                                             'lunar': '78.4611359976',
#                                             'miles': '18749146.8800321904'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '18956.4025143398',
#                                                 'kilometers_per_second': '5.2656673651',
#                                                 'miles_per_hour': '11778.7713289796'}},
#                          {'close_approach_date': '1920-08-27',
#                           'close_approach_date_full': '1920-Aug-27 00:15',
#                           'epoch_date_close_approach': -1557272700000,
#                           'miss_distance': {'astronomical': '0.3922380985',
#                                             'kilometers': '58677984.068450195',
#                                             'lunar': '152.5806203165',
#                                             'miles': '36460808.589974891'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '24779.5909882693',
#                                                 'kilometers_per_second': '6.883219719',
#                                                 'miles_per_hour': '15397.0741893499'}},
#                          {'close_approach_date': '1924-12-19',
#                           'close_approach_date_full': '1924-Dec-19 14:32',
#                           'epoch_date_close_approach': -1421141280000,
#                           'miss_distance': {'astronomical': '0.1361644677',
#                                             'kilometers': '20369914.337603799',
#                                             'lunar': '52.9679779353',
#                                             'miles': '12657277.8436144662'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '7522.0846195222',
#                                                 'kilometers_per_second': '2.0894679499',
#                                                 'miles_per_hour': '4673.9308570581'}},
#                          {'close_approach_date': '1925-12-28',
#                           'close_approach_date_full': '1925-Dec-28 17:32',
#                           'epoch_date_close_approach': -1388816880000,
#                           'miss_distance': {'astronomical': '0.3364558397',
#                                             'kilometers': '50333076.968181439',
#                                             'lunar': '130.8813216433',
#                                             'miles': '31275523.7627202982'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '65215.3583012238',
#                                                 'kilometers_per_second': '18.1153773059',
#                                                 'miles_per_hour': '40522.2874955576'}},
#                          {'close_approach_date': '1926-10-17',
#                           'close_approach_date_full': '1926-Oct-17 17:33',
#                           'epoch_date_close_approach': -1363501620000,
#                           'miss_distance': {'astronomical': '0.444902641',
#                                             'kilometers': '66556487.45097467',
#                                             'lunar': '173.067127349',
#                                             'miles': '41356283.585683646'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '30428.2130679897',
#                                                 'kilometers_per_second': '8.4522814078',
#                                                 'miles_per_hour': '18906.9082810517'}},
#                          {'close_approach_date': '1927-07-07',
#                           'close_approach_date_full': '1927-Jul-07 13:10',
#                           'epoch_date_close_approach': -1340794200000,
#                           'miss_distance': {'astronomical': '0.1746977072',
#                                             'kilometers': '26134404.891003664',
#                                             'lunar': '67.9574081008',
#                                             'miles': '16239166.1791280032'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '48367.5451178022',
#                                                 'kilometers_per_second': '13.4354291994',
#                                                 'miles_per_hour': '30053.7115761144'}},
#                          {'close_approach_date': '1932-12-06',
#                           'close_approach_date_full': '1932-Dec-06 07:38',
#                           'epoch_date_close_approach': -1169828520000,
#                           'miss_distance': {'astronomical': '0.2949624723',
#                                             'kilometers': '44125757.586014001',
#                                             'lunar': '114.7404017247',
#                                             'miles': '27418474.3523991738'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '25801.9548523683',
#                                                 'kilometers_per_second': '7.1672096812',
#                                                 'miles_per_hour': '16032.3313359063'}},
#                          {'close_approach_date': '1933-04-15',
#                           'close_approach_date_full': '1933-Apr-15 01:32',
#                           'epoch_date_close_approach': -1158618480000,
#                           'miss_distance': {'astronomical': '0.2180161376',
#                                             'kilometers': '32614749.810586912',
#                                             'lunar': '84.8082775264',
#                                             'miles': '20265865.7916149056'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '26552.3336311798',
#                                                 'kilometers_per_second': '7.3756482309',
#                                                 'miles_per_hour': '16498.5875276628'}},
#                          {'close_approach_date': '1933-07-30',
#                           'close_approach_date_full': '1933-Jul-30 19:06',
#                           'epoch_date_close_approach': -1149396840000,
#                           'miss_distance': {'astronomical': '0.3178390955',
#                                             'kilometers': '47548051.689526585',
#                                             'lunar': '123.6394081495',
#                                             'miles': '29544989.300513473'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '19585.8815765606',
#                                                 'kilometers_per_second': '5.4405226602',
#                                                 'miles_per_hour': '12169.9051385023'}},
#                          {'close_approach_date': '1939-01-04',
#                           'close_approach_date_full': '1939-Jan-04 13:15',
#                           'epoch_date_close_approach': -978000300000,
#                           'miss_distance': {'astronomical': '0.1772544169',
#                                             'kilometers': '26516883.216332003',
#                                             'lunar': '68.9519681741',
#                                             'miles': '16476827.1899995214'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '47802.6853186752',
#                                                 'kilometers_per_second': '13.2785236996',
#                                                 'miles_per_hour': '29702.7296637068'}},
#                          {'close_approach_date': '1939-10-02',
#                           'close_approach_date_full': '1939-Oct-02 23:40',
#                           'epoch_date_close_approach': -954548400000,
#                           'miss_distance': {'astronomical': '0.4508022257',
#                                             'kilometers': '67439052.755979259',
#                                             'lunar': '175.3620657973',
#                                             'miles': '41904684.2365374142'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '29767.9777441789',
#                                                 'kilometers_per_second': '8.2688827067',
#                                                 'miles_per_hour': '18496.6637266538'}},
#                          {'close_approach_date': '1940-07-15',
#                           'close_approach_date_full': '1940-Jul-15 08:32',
#                           'epoch_date_close_approach': -929806080000,
#                           'miss_distance': {'astronomical': '0.3345331279',
#                                             'kilometers': '50045443.378277573',
#                                             'lunar': '130.1333867531',
#                                             'miles': '31096796.5376455874'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '64571.4380861536',
#                                                 'kilometers_per_second': '17.9365105795',
#                                                 'miles_per_hour': '40122.1805152547'}},
#                          {'close_approach_date': '1945-11-18',
#                           'close_approach_date_full': '1945-Nov-18 06:11',
#                           'epoch_date_close_approach': -761161740000,
#                           'miss_distance': {'astronomical': '0.368752785',
#                                             'kilometers': '55164631.19256795',
#                                             'lunar': '143.444833365',
#                                             'miles': '34277712.34441971'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '28578.7013768642',
#                                                 'kilometers_per_second': '7.9385281602',
#                                                 'miles_per_hour': '17757.693641641'}},
#                          {'close_approach_date': '1946-05-31',
#                           'close_approach_date_full': '1946-May-31 01:45',
#                           'epoch_date_close_approach': -744416100000,
#                           'miss_distance': {'astronomical': '0.144681548',
#                                             'kilometers': '21644051.40910276',
#                                             'lunar': '56.281122172',
#                                             'miles': '13448989.907667688'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '24131.1423383952',
#                                                 'kilometers_per_second': '6.703095094',
#                                                 'miles_per_hour': '14994.1534157656'}},
#                          {'close_approach_date': '1952-01-09',
#                           'close_approach_date_full': '1952-Jan-09 10:55',
#                           'epoch_date_close_approach': -567349500000,
#                           'miss_distance': {'astronomical': '0.0732960718',
#                                             'kilometers': '10964936.220647066',
#                                             'lunar': '28.5121719302',
#                                             'miles': '6813295.4308028708'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '33228.6612663955',
#                                                 'kilometers_per_second': '9.2301836851',
#                                                 'miles_per_hour': '20646.9978852222'}},
#                          {'close_approach_date': '1952-09-18',
#                           'close_approach_date_full': '1952-Sep-18 12:09',
#                           'epoch_date_close_approach': -545485860000,
#                           'miss_distance': {'astronomical': '0.4381150068',
#                                             'kilometers': '65541071.832315516',
#                                             'lunar': '170.4267376452',
#                                             'miles': '40725333.5777894808'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '28395.2867389957',
#                                                 'kilometers_per_second': '7.8875796497',
#                                                 'miles_per_hour': '17643.726918461'}},
#                          {'close_approach_date': '1953-07-22',
#                           'close_approach_date_full': '1953-Jul-22 08:41',
#                           'epoch_date_close_approach': -518973540000,
#                           'miss_distance': {'astronomical': '0.4679436359',
#                                             'kilometers': '70003371.210695533',
#                                             'lunar': '182.0300743651',
#                                             'miles': '43498077.8376550354'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '78393.0787872667',
#                                                 'kilometers_per_second': '21.7758552187',
#                                                 'miles_per_hour': '48710.4105386769'}},
#                          {'close_approach_date': '1958-11-06',
#                           'close_approach_date_full': '1958-Nov-06 23:01',
#                           'epoch_date_close_approach': -351910740000,
#                           'miss_distance': {'astronomical': '0.4052163429',
#                                             'kilometers': '60619501.787029623',
#                                             'lunar': '157.6291573881',
#                                             'miles': '37667211.7586418774'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '29821.8802303539',
#                                                 'kilometers_per_second': '8.2838556195',
#                                                 'miles_per_hour': '18530.1566353552'}},
#                          {'close_approach_date': '1959-06-22',
#                           'close_approach_date_full': '1959-Jun-22 11:57',
#                           'epoch_date_close_approach': -332251380000,
#                           'miss_distance': {'astronomical': '0.0488510304',
#                                             'kilometers': '7308010.095145248',
#                                             'lunar': '19.0030508256',
#                                             'miles': '4540986.9047625024'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '28870.7474765425',
#                                                 'kilometers_per_second': '8.0196520768',
#                                                 'miles_per_hour': '17939.1597306328'}},
#                          {'close_approach_date': '1965-01-09',
#                           'close_approach_date_full': '1965-Jan-09 06:20',
#                           'epoch_date_close_approach': -157052400000,
#                           'miss_distance': {'astronomical': '0.0918943104',
#                                             'kilometers': '13747193.100958848',
#                                             'lunar': '35.7468867456',
#                                             'miles': '8542109.6900461824'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '27010.4648156398',
#                                                 'kilometers_per_second': '7.5029068932',
#                                                 'miles_per_hour': '16783.2524294735'}},
#                          {'close_approach_date': '1965-09-11',
#                           'close_approach_date_full': '1965-Sep-11 11:07',
#                           'epoch_date_close_approach': -135867180000,
#                           'miss_distance': {'astronomical': '0.4256120781',
#                                             'kilometers': '63670660.330033647',
#                                             'lunar': '165.5630983809',
#                                             'miles': '39563113.7631204486'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '27282.9212351798',
#                                                 'kilometers_per_second': '7.578589232',
#                                                 'miles_per_hour': '16952.5462530483'}},
#                          {'close_approach_date': '1970-12-22',
#                           'close_approach_date_full': '1970-Dec-22 03:21',
#                           'epoch_date_close_approach': 30684060000,
#                           'miss_distance': {'astronomical': '0.4970942197',
#                                             'kilometers': '74364236.456432039',
#                                             'lunar': '193.3696514633',
#                                             'miles': '46207793.8501545782'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '82786.0987089522',
#                                                 'kilometers_per_second': '22.9961385303',
#                                                 'miles_per_hour': '51440.0622783487'}},
#                          {'close_approach_date': '1971-11-02',
#                           'close_approach_date_full': '1971-Nov-02 20:26',
#                           'epoch_date_close_approach': 57961560000,
#                           'miss_distance': {'astronomical': '0.4161213859',
#                                             'kilometers': '62250872.992088033',
#                                             'lunar': '161.8712191151',
#                                             'miles': '38680898.8201715354'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '30031.6590584928',
#                                                 'kilometers_per_second': '8.3421275162',
#                                                 'miles_per_hour': '18660.5050410952'}},
#                          {'close_approach_date': '1972-06-25',
#                           'close_approach_date_full': '1972-Jun-25 18:40',
#                           'epoch_date_close_approach': 78345600000,
#                           'miss_distance': {'astronomical': '0.0287692703',
#                                             'kilometers': '4303821.558334261',
#                                             'lunar': '11.1912461467',
#                                             'miles': '2674270.7087683618'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '32284.6644404957',
#                                                 'kilometers_per_second': '8.9679623446',
#                                                 'miles_per_hour': '20060.4349685958'}},
#                          {'close_approach_date': '1978-01-06',
#                           'close_approach_date_full': '1978-Jan-06 06:31',
#                           'epoch_date_close_approach': 252916260000,
#                           'miss_distance': {'astronomical': '0.1452310557',
#                                             'kilometers': '21726256.590571359',
#                                             'lunar': '56.4948806673',
#                                             'miles': '13500069.8388243942'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '22857.4885716318',
#                                                 'kilometers_per_second': '6.349302381',
#                                                 'miles_per_hour': '14202.7544960786'}},
#                          {'close_approach_date': '1978-09-03',
#                           'close_approach_date_full': '1978-Sep-03 16:17',
#                           'epoch_date_close_approach': 273687420000,
#                           'miss_distance': {'astronomical': '0.4089770829',
#                                             'kilometers': '61182100.480653423',
#                                             'lunar': '159.0920852481',
#                                             'miles': '38016794.3764983174'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '26109.7467564453',
#                                                 'kilometers_per_second': '7.2527074323',
#                                                 'miles_per_hour': '16223.5812554146'}},
#                          {'close_approach_date': '1983-12-26',
#                           'close_approach_date_full': '1983-Dec-26 09:46',
#                           'epoch_date_close_approach': 441279960000,
#                           'miss_distance': {'astronomical': '0.4048345509',
#                                             'kilometers': '60562386.517046583',
#                                             'lunar': '157.4806403001',
#                                             'miles': '37631721.9755575254'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '72737.748777186',
#                                                 'kilometers_per_second': '20.2049302159',
#                                                 'miles_per_hour': '45196.4083999132'}},
#                          {'close_approach_date': '1984-10-24',
#                           'close_approach_date_full': '1984-Oct-24 02:43',
#                           'epoch_date_close_approach': 467433780000,
#                           'miss_distance': {'astronomical': '0.4350098908',
#                                             'kilometers': '65076553.092612596',
#                                             'lunar': '169.2188475212',
#                                             'miles': '40436695.0172859848'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '30503.8938075811',
#                                                 'kilometers_per_second': '8.4733038354',
#                                                 'miles_per_hour': '18953.9333494939'}},
#                          {'close_approach_date': '1985-07-02',
#                           'close_approach_date_full': '1985-Jul-02 21:01',
#                           'epoch_date_close_approach': 489186060000,
#                           'miss_distance': {'astronomical': '0.1010072079',
#                                             'kilometers': '15110463.156487173',
#                                             'lunar': '39.2918038731',
#                                             'miles': '9389206.4221540674'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '40996.5771669206',
#                                                 'kilometers_per_second': '11.3879381019',
#                                                 'miles_per_hour': '25473.6787401902'}},
#                          {'close_approach_date': '1990-12-18',
#                           'close_approach_date_full': '1990-Dec-18 07:59',
#                           'epoch_date_close_approach': 661507140000,
#                           'miss_distance': {'astronomical': '0.2439796497',
#                                             'kilometers': '36498835.918466139',
#                                             'lunar': '94.9080837333',
#                                             'miles': '22679324.9854611582'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '23867.4015686739',
#                                                 'kilometers_per_second': '6.6298337691',
#                                                 'miles_per_hour': '14830.2751580463'}},
#                          {'close_approach_date': '1991-03-23',
#                           'close_approach_date_full': '1991-Mar-23 17:01',
#                           'epoch_date_close_approach': 669747660000,
#                           'miss_distance': {'astronomical': '0.2222873661',
#                                             'kilometers': '33253716.496470207',
#                                             'lunar': '86.4697854129',
#                                             'miles': '20662901.2794425766'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '24935.8838158644',
#                                                 'kilometers_per_second': '6.9266343933',
#                                                 'miles_per_hour': '15494.1884743631'}},
#                          {'close_approach_date': '1991-08-17',
#                           'close_approach_date_full': '1991-Aug-17 15:32',
#                           'epoch_date_close_approach': 682443120000,
#                           'miss_distance': {'astronomical': '0.3635087188',
#                                             'kilometers': '54380130.058908956',
#                                             'lunar': '141.4048916132',
#                                             'miles': '33790245.9440813528'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '22827.887940325',
#                                                 'kilometers_per_second': '6.3410799834',
#                                                 'miles_per_hour': '14184.3618149203'}},
#                          {'close_approach_date': '1996-12-31',
#                           'close_approach_date_full': '1996-Dec-31 18:58',
#                           'epoch_date_close_approach': 852058680000,
#                           'miss_distance': {'astronomical': '0.2617186424',
#                                             'kilometers': '39152551.442331688',
#                                             'lunar': '101.8085518936',
#                                             'miles': '24328267.3495177744'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '57151.7509397821',
#                                                 'kilometers_per_second': '15.8754863722',
#                                                 'miles_per_hour': '35511.8754658885'}},
#                          {'close_approach_date': '1997-10-10',
#                           'close_approach_date_full': '1997-Oct-10 21:51',
#                           'epoch_date_close_approach': 876520260000,
#                           'miss_distance': {'astronomical': '0.4499912937',
#                                             'kilometers': '67317739.056064419',
#                                             'lunar': '175.0466132493',
#                                             'miles': '41829303.3988662222'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '30320.8893602776',
#                                                 'kilometers_per_second': '8.4224692667',
#                                                 'miles_per_hour': '18840.2215027792'}},
#                          {'close_approach_date': '1998-07-11',
#                           'close_approach_date_full': '1998-Jul-11 12:30',
#                           'epoch_date_close_approach': 900160200000,
#                           'miss_distance': {'astronomical': '0.2461741944',
#                                             'kilometers': '36827135.131205928',
#                                             'lunar': '95.7617616216',
#                                             'miles': '22883320.6568526864'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '55503.2990058206',
#                                                 'kilometers_per_second': '15.4175830572',
#                                                 'miles_per_hour': '34487.5915405889'}},
#                          {'close_approach_date': '2003-02-15',
#                           'close_approach_date_full': '2003-Feb-15 17:49',
#                           'epoch_date_close_approach': 1045331340000,
#                           'miss_distance': {'astronomical': '0.1392391727',
#                                             'kilometers': '20829883.656482149',
#                                             'lunar': '54.1640381803',
#                                             'miles': '12943089.5251016962'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '8396.5739157628',
#                                                 'kilometers_per_second': '2.3323816433',
#                                                 'miles_per_hour': '5217.304497825'}},
#                          {'close_approach_date': '2003-11-28',
#                           'close_approach_date_full': '2003-Nov-28 15:41',
#                           'epoch_date_close_approach': 1070034060000,
#                           'miss_distance': {'astronomical': '0.3309479051',
#                                             'kilometers': '49509101.683922137',
#                                             'lunar': '128.7387350839',
#                                             'miles': '30763529.2625820106'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '27266.6707204117',
#                                                 'kilometers_per_second': '7.5740752001',
#                                                 'miles_per_hour': '16942.4488151358'}},
#                          {'close_approach_date': '2004-05-03',
#                           'close_approach_date_full': '2004-May-03 17:57',
#                           'epoch_date_close_approach': 1083607020000,
#                           'miss_distance': {'astronomical': '0.1969886085',
#                                             'kilometers': '29469076.245863895',
#                                             'lunar': '76.6285687065',
#                                             'miles': '18311234.875935951'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '26142.6384795889',
#                                                 'kilometers_per_second': '7.2618440221',
#                                                 'miles_per_hour': '16244.0188930535'}},
#                          {'close_approach_date': '2010-01-06',
#                           'close_approach_date_full': '2010-Jan-06 13:52',
#                           'epoch_date_close_approach': 1262785920000,
#                           'miss_distance': {'astronomical': '0.1258552253',
#                                             'kilometers': '18827673.633250111',
#                                             'lunar': '48.9576826417',
#                                             'miles': '11698973.9070730918'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '41891.0091811711',
#                                                 'kilometers_per_second': '11.6363914392',
#                                                 'miles_per_hour': '26029.4440103782'}},
#                          {'close_approach_date': '2010-09-27',
#                           'close_approach_date_full': '2010-Sep-27 21:53',
#                           'epoch_date_close_approach': 1285624380000,
#                           'miss_distance': {'astronomical': '0.4475361797',
#                                             'kilometers': '66950459.231057239',
#                                             'lunar': '174.0915739033',
#                                             'miles': '41601086.2981743382'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '29355.5764089381',
#                                                 'kilometers_per_second': '8.1543267803',
#                                                 'miles_per_hour': '18240.4135747649'}},
#                          {'close_approach_date': '2011-07-18',
#                           'close_approach_date_full': '2011-Jul-18 23:20',
#                           'epoch_date_close_approach': 1311031200000,
#                           'miss_distance': {'astronomical': '0.3838979145',
#                                             'kilometers': '57430310.306642115',
#                                             'lunar': '149.3362887405',
#                                             'miles': '35685540.064066587'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '69611.3588265754',
#                                                 'kilometers_per_second': '19.3364885629',
#                                                 'miles_per_hour': '43253.7912664351'}},
#                          {'close_approach_date': '2016-11-14',
#                           'close_approach_date_full': '2016-Nov-14 21:24',
#                           'epoch_date_close_approach': 1479158640000,
#                           'miss_distance': {'astronomical': '0.379795829',
#                                             'kilometers': '56816647.05328423',
#                                             'lunar': '147.740577481',
#                                             'miles': '35304227.400133174'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '28993.2458179313',
#                                                 'kilometers_per_second': '8.0536793939',
#                                                 'miles_per_hour': '18015.2754361474'}},
#                          {'close_approach_date': '2017-06-07',
#                           'close_approach_date_full': '2017-Jun-07 19:16',
#                           'epoch_date_close_approach': 1496862960000,
#                           'miss_distance': {'astronomical': '0.121601078',
#                                             'kilometers': '18191262.25850386',
#                                             'lunar': '47.302819342',
#                                             'miles': '11303526.215958868'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '24399.5191496442',
#                                                 'kilometers_per_second': '6.7776442082',
#                                                 'miles_per_hour': '15160.9123293997'}},
#                          {'close_approach_date': '2018-06-28',
#                           'close_approach_date_full': '2018-Jun-28 17:53',
#                           'epoch_date_close_approach': 1530208380000,
#                           'miss_distance': {'astronomical': '0.1299705756',
#                                             'kilometers': '19443321.272433972',
#                                             'lunar': '50.5585539084',
#                                             'miles': '12081519.6111819336'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '8131.6612091167',
#                                                 'kilometers_per_second': '2.2587947803',
#                                                 'miles_per_hour': '5052.6980440759'}},
#                          {'close_approach_date': '2023-01-09',
#                           'close_approach_date_full': '2023-Jan-09 13:59',
#                           'epoch_date_close_approach': 1673272740000,
#                           'miss_distance': {'astronomical': '0.0725378004',
#                                             'kilometers': '10851500.434325148',
#                                             'lunar': '28.2172043556',
#                                             'miles': '6742809.7016491224'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '32387.333793389',
#                                                 'kilometers_per_second': '8.9964816093',
#                                                 'miles_per_hour': '20124.2297117866'}},
#                          {'close_approach_date': '2023-09-19',
#                           'close_approach_date_full': '2023-Sep-19 00:06',
#                           'epoch_date_close_approach': 1695081960000,
#                           'miss_distance': {'astronomical': '0.4367402847',
#                                             'kilometers': '65335416.334313589',
#                                             'lunar': '169.8919707483',
#                                             'miles': '40597545.1769579682'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '28339.6707051877',
#                                                 'kilometers_per_second': '7.8721307514',
#                                                 'miles_per_hour': '17609.1692778984'}},
#                          {'close_approach_date': '2024-07-22',
#                           'close_approach_date_full': '2024-Jul-22 14:57',
#                           'epoch_date_close_approach': 1721660220000,
#                           'miss_distance': {'astronomical': '0.4698905676',
#                                             'kilometers': '70294628.046051012',
#                                             'lunar': '182.7874307964',
#                                             'miles': '43679056.4430554856'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '78572.9442673429',
#                                                 'kilometers_per_second': '21.825817852',
#                                                 'miles_per_hour': '48822.1719532276'}},
#                          {'close_approach_date': '2029-11-08',
#                           'close_approach_date_full': '2029-Nov-08 09:25',
#                           'epoch_date_close_approach': 1888824300000,
#                           'miss_distance': {'astronomical': '0.4003634279',
#                                             'kilometers': '59893516.039738573',
#                                             'lunar': '155.7413734531',
#                                             'miles': '37216105.1333673874'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '29746.2081994042',
#                                                 'kilometers_per_second': '8.2628356109',
#                                                 'miles_per_hour': '18483.1369781242'}},
#                          {'close_approach_date': '2030-06-20',
#                           'close_approach_date_full': '2030-Jun-20 05:07',
#                           'epoch_date_close_approach': 1908162420000,
#                           'miss_distance': {'astronomical': '0.0651511429',
#                                             'kilometers': '9746472.205905623',
#                                             'lunar': '25.3437945881',
#                                             'miles': '6056177.0000906774'},
#                           'orbiting_body': 'Earth',
# ...
#                           'miss_distance': {'astronomical': '0.1150004108',
#                                             'kilometers': '17203816.504804996',
#                                             'lunar': '44.7351598012',
#                                             'miles': '10689955.8762451048'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '42267.1806080543',
#                                                 'kilometers_per_second': '11.7408835022',
#                                                 'miles_per_hour': '26263.1823061546'}},
#                          {'close_approach_date': '2167-01-03',
#                           'close_approach_date_full': '2167-Jan-03 22:53',
#                           'epoch_date_close_approach': 6216994380000,
#                           'miss_distance': {'astronomical': '0.1705768415',
#                                             'kilometers': '25517932.159727605',
#                                             'lunar': '66.3543913435',
#                                             'miles': '15856107.786566749'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '22184.4765631885',
#                                                 'kilometers_per_second': '6.1623546009',
#                                                 'miles_per_hour': '13784.5710067212'}},
#                          {'close_approach_date': '2167-09-04',
#                           'close_approach_date_full': '2167-Sep-04 01:03',
#                           'epoch_date_close_approach': 6237997380000,
#                           'miss_distance': {'astronomical': '0.4019435817',
#                                             'kilometers': '60129903.682490979',
#                                             'lunar': '156.3560532813',
#                                             'miles': '37362989.6034503502'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '25646.0985520901',
#                                                 'kilometers_per_second': '7.1239162645',
#                                                 'miles_per_hour': '15935.4882919917'}},
#                          {'close_approach_date': '2172-12-24',
#                           'close_approach_date_full': '2172-Dec-24 10:53',
#                           'epoch_date_close_approach': 6405475980000,
#                           'miss_distance': {'astronomical': '0.4677830644',
#                                             'kilometers': '69979350.056312828',
#                                             'lunar': '181.9676120516',
#                                             'miles': '43483151.7844519064'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '79561.3548158532',
#                                                 'kilometers_per_second': '22.1003763377',
#                                                 'miles_per_hour': '49436.3318298839'}},
#                          {'close_approach_date': '2173-11-02',
#                           'close_approach_date_full': '2173-Nov-02 13:07',
#                           'epoch_date_close_approach': 6432527220000,
#                           'miss_distance': {'astronomical': '0.4173355781',
#                                             'kilometers': '62432513.558978647',
#                                             'lunar': '162.3435398809',
#                                             'miles': '38793765.0347614486'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '30265.1776205803',
#                                                 'kilometers_per_second': '8.4069937835',
#                                                 'miles_per_hour': '18805.6043942989'}},
#                          {'close_approach_date': '2174-06-28',
#                           'close_approach_date_full': '2174-Jun-28 18:01',
#                           'epoch_date_close_approach': 6453108060000,
#                           'miss_distance': {'astronomical': '0.0341017149',
#                                             'kilometers': '5101543.912387263',
#                                             'lunar': '13.2655670961',
#                                             'miles': '3169952.3945117094'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '32787.1857746523',
#                                                 'kilometers_per_second': '9.1075516041',
#                                                 'miles_per_hour': '20372.6821831444'}},
#                          {'close_approach_date': '2179-01-22',
#                           'close_approach_date_full': '2179-Jan-22 18:07',
#                           'epoch_date_close_approach': 6597310020000,
#                           'miss_distance': {'astronomical': '0.1265835698',
#                                             'kilometers': '18936632.419076326',
#                                             'lunar': '49.2410086522',
#                                             'miles': '11766677.7571162588'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '8504.8214485078',
#                                                 'kilometers_per_second': '2.3624504024',
#                                                 'miles_per_hour': '5284.5653050464'}},
#                          {'close_approach_date': '2180-01-11',
#                           'close_approach_date_full': '2180-Jan-11 07:19',
#                           'epoch_date_close_approach': 6627856740000,
#                           'miss_distance': {'astronomical': '0.1105491931',
#                                             'kilometers': '16537923.817978697',
#                                             'lunar': '43.0036361159',
#                                             'miles': '10276189.3472601386'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '25028.356969812',
#                                                 'kilometers_per_second': '6.9523213805',
#                                                 'miles_per_hour': '15551.6476960479'}},
#                          {'close_approach_date': '2180-09-11',
#                           'close_approach_date_full': '2180-Sep-11 17:17',
#                           'epoch_date_close_approach': 6648974220000,
#                           'miss_distance': {'astronomical': '0.4212757978',
#                                             'kilometers': '63021962.033430686',
#                                             'lunar': '163.8762853442',
#                                             'miles': '39160031.3327920268'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '27151.3482288246',
#                                                 'kilometers_per_second': '7.5420411747',
#                                                 'miles_per_hour': '16870.7919036272'}},
#                          {'close_approach_date': '2186-11-06',
#                           'close_approach_date_full': '2186-Nov-06 01:18',
#                           'epoch_date_close_approach': 6843057480000,
#                           'miss_distance': {'astronomical': '0.4105165405',
#                                             'kilometers': '61412400.058568735',
#                                             'lunar': '159.6909342545',
#                                             'miles': '38159895.898509143'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '30109.5340056059',
#                                                 'kilometers_per_second': '8.363759446',
#                                                 'miles_per_hour': '18708.8935047611'}},
#                          {'close_approach_date': '2187-06-26',
#                           'close_approach_date_full': '2187-Jun-26 02:37',
#                           'epoch_date_close_approach': 6863107020000,
#                           'miss_distance': {'astronomical': '0.0402621383',
#                                             'kilometers': '6023130.131325421',
#                                             'lunar': '15.6619717987',
#                                             'miles': '3742599.5169599698'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '30165.8310796706',
#                                                 'kilometers_per_second': '8.3793975221',
#                                                 'miles_per_hour': '18743.8743172542'}},
#                          {'close_approach_date': '2193-01-10',
#                           'close_approach_date_full': '2193-Jan-10 21:55',
#                           'epoch_date_close_approach': 7038136500000,
#                           'miss_distance': {'astronomical': '0.0818011788',
#                                             'kilometers': '12237282.111969156',
#                                             'lunar': '31.8206585532',
#                                             'miles': '7603894.5071041128'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '28591.2574831794',
#                                                 'kilometers_per_second': '7.9420159675',
#                                                 'miles_per_hour': '17765.4955178122'}},
#                          {'close_approach_date': '2193-09-16',
#                           'close_approach_date_full': '2193-Sep-16 23:41',
#                           'epoch_date_close_approach': 7059656460000,
#                           'miss_distance': {'astronomical': '0.4305045381',
#                                             'kilometers': '64402561.925093847',
#                                             'lunar': '167.4662653209',
#                                             'miles': '40017896.3257432086'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '27939.6618635057',
#                                                 'kilometers_per_second': '7.7610171843',
#                                                 'miles_per_hour': '17360.6193395766'}},
#                          {'close_approach_date': '2194-07-26',
#                           'close_approach_date_full': '2194-Jul-26 01:01',
#                           'epoch_date_close_approach': 7086618060000,
#                           'miss_distance': {'astronomical': '0.4918196494',
#                                             'kilometers': '73575171.974386778',
#                                             'lunar': '191.3178436166',
#                                             'miles': '45717491.9166144164'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '81015.3507130747',
#                                                 'kilometers_per_second': '22.504264087',
#                                                 'miles_per_hour': '50339.7883361325'}},
#                          {'close_approach_date': '2199-11-12',
#                           'close_approach_date_full': '2199-Nov-12 07:47',
#                           'epoch_date_close_approach': 7253826420000,
#                           'miss_distance': {'astronomical': '0.3929989145',
#                                             'kilometers': '58791800.521512115',
#                                             'lunar': '152.8765777405',
#                                             'miles': '36531530.854472587'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '29592.9275188938',
#                                                 'kilometers_per_second': '8.2202576441',
#                                                 'miles_per_hour': '18387.8943241704'}},
#                          {'close_approach_date': '2200-06-17',
#                           'close_approach_date_full': '2200-Jun-17 14:21',
#                           'epoch_date_close_approach': 7272598860000,
#                           'miss_distance': {'astronomical': '0.0918662215',
#                                             'kilometers': '13742991.061348205',
#                                             'lunar': '35.7359601635',
#                                             'miles': '8539498.663707029'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '25707.5830489263',
#                                                 'kilometers_per_second': '7.1409952914',
#                                                 'miles_per_hour': '15973.692367262'}}],
#  'designation': '226554',
#  'estimated_diameter': {'feet': {'estimated_diameter_max': 2301.5744618737,
#                                  'estimated_diameter_min': 1029.2953904054},
#                         'kilometers': {'estimated_diameter_max': 0.7015198735,
#                                        'estimated_diameter_min': 0.313729225},
#                         'meters': {'estimated_diameter_max': 701.5198735305,
#                                    'estimated_diameter_min': 313.7292249562},
#                         'miles': {'estimated_diameter_max': 0.4359041053,
#                                   'estimated_diameter_min': 0.1949422422}},
#  'id': '2226554',
#  'is_potentially_hazardous_asteroid': True,
#  'is_sentry_object': False,
#  'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2226554?api_key=DEMO_KEY'},
#  'name': '226554 (2003 WR21)',
#  'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2226554',
#  'neo_reference_id': '2226554',
#  'orbital_data': {'aphelion_distance': '1.410933079112178',
#                   'ascending_node_longitude': '85.7759669015775',
#                   'data_arc_in_days': 11771,
#                   'eccentricity': '.2616161178389927',
#                   'epoch_osculation': '2460000.5',
#                   'equinox': 'J2000',
#                   'first_observation_date': '1990-10-24',
#                   'inclination': '9.264882650378096',
#                   'jupiter_tisserand_invariant': '5.536',
#                   'last_observation_date': '2023-01-15',
#                   'mean_anomaly': '343.040342715377',
#                   'mean_motion': '.8333650706102882',
#                   'minimum_orbit_intersection': '.0302692',
#                   'observations_used': 462,
#                   'orbit_class': {'orbit_class_description': 'Near-Earth '
#                                                              'asteroid orbits '
#                                                              'which cross the '
#                                                              'Earth’s orbit '
#                                                              'similar to that '
#                                                              'of 1862 Apollo',
#                                   'orbit_class_range': 'a (semi-major axis) > '
#                                                        '1.0 AU; q (perihelion) '
#                                                        '< 1.017 AU',
#                                   'orbit_class_type': 'APO'},
#                   'orbit_determination_date': '2023-03-04 05:18:40',
#                   'orbit_id': '107',
#                   'orbit_uncertainty': '0',
#                   'orbital_period': '431.9835480221957',
#                   'perihelion_argument': '108.0903738041211',
#                   'perihelion_distance': '.8257743617042069',
#                   'perihelion_time': '2460020.850813686255',
#                   'semi_major_axis': '1.118353720408192'}}

# %% [markdown]
# Notice that the `miss_distance` field contains the distance (in various units) by which the NEO missed an "orbiting body".
#
# ## Exercise 2
#
# In the code cell below, write a python function that takes a list of "close approach data" as a parameter,
# and returns a 2-tuple with the (date, miss km) of the closest approach to Earth in the list (where "miss km" is the miss distance in km).
#
# Hints:
# * notice the input is a list of dictionaries.  Each dictionary has a 'close_approach_date", "orbiting_body", and 'miss_distance' field.
# * we are only interested in the closest approach to "Earth"
# * use a loop if that is easier to understand - we will look at more compact algorithms to solve this problem in class.
#
# Add at least one unit test to check your work - note the test data only needs dictionaries with the fields your function actually uses.

# %%
def CloseApproaches(close_approach_data):
  return [(item['close_approach_date'],item['miss_distance']['kilometeres']) for item in close_approach_data if item['orbiting_body'] == 'Earth']

# %% [markdown]
# ## OPTIONAL - Take your skills to the next level...
# ## Exercise 3
#
# In the code cell below, write a complete program that:
#  1. fetches the list of NEO's for this week.
#  2. for each NEO, fetch it's complete orbital data and determine its closest approach to Earth
#  3. identify which NEO from this week's data makes the closet approach to earth
#  4. print a nice message with information about the NEO, which it will approach the Earth, and how close it will come.
#
# Hints:
# * you'll need the start and end date - end date is today, see if you can use a [`timedelta`](https://docs.python.org/3/library/datetime.html#timedelta-objects) object to ge the start date (you can do basic "date math" with `timedelta` and `date` objects!)
# * you may need to modify the function we wrote in Ex. 2 to return a triple with the NEO's id included;
# * lots of opportunity here for more practice with list comprehensions

# %%
url = f'https://api.nasa.gov/neo/rest/v1/feed?start_date={datetime.date.today()}&end_date={datetime.date.today()-datetime.timedelta(days=7)}&api_key=DEMO_KEY'
response = requests.request("GET", url, headers={}, data={})
data = sum(json.loads(response.text)['near_earth_objects'].values(),[])
pprint(data[0])
NEOs = [(item['id'],item['close_approach_data'][0]['miss_distance']['kilometers']) for item in data]
min = 0
for neo in NEOs:
  if min == 0 or neo[1]<min[1]:
    min = neo
print(f'NEO {min[0]} will be the closest NEO to Earth by {min[1]} kms.')
# Out:
# {'absolute_magnitude_h': 19.3,
#  'close_approach_data': [{'close_approach_date': '2023-03-03',
#                           'close_approach_date_full': '2023-Mar-03 13:13',
#                           'epoch_date_close_approach': 1677849180000,
#                           'miss_distance': {'astronomical': '0.3708796769',
#                                             'kilometers': '55482809.690528203',
#                                             'lunar': '144.2721943141',
#                                             'miles': '34475419.2952590814'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '101785.5029854328',
#                                                 'kilometers_per_second': '28.2737508293',
#                                                 'miles_per_hour': '63245.5532300319'}}],
#  'estimated_diameter': {'feet': {'estimated_diameter_max': 2691.6899315481,
#                                  'estimated_diameter_min': 1203.7603322587},
#                         'kilometers': {'estimated_diameter_max': 0.8204270649,
#                                        'estimated_diameter_min': 0.3669061375},
#                         'meters': {'estimated_diameter_max': 820.4270648822,
#                                    'estimated_diameter_min': 366.9061375314},
#                         'miles': {'estimated_diameter_max': 0.5097895857,
#                                   'estimated_diameter_min': 0.2279848336}},
#  'id': '2065909',
#  'is_potentially_hazardous_asteroid': True,
#  'is_sentry_object': False,
#  'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2065909?api_key=DEMO_KEY'},
#  'name': '65909 (1998 FH12)',
#  'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2065909',
#  'neo_reference_id': '2065909'}
# NEO 54342518 will be the closest NEO to Earth by 1053568.401193326 kms.

# %%
from dataclasses import dataclass
@dataclass
class Asteroid():
  id: str
  name: str
  est_diameter: float
  is_potentially_dangerous: bool

  def __str__(self,name,id):
    return f'Asteroid ID:{self.id} named {self.name}.'

  @classmethod
  def from_NEO(cls,neo_id):
    url = f'https://api.nasa.gov/neo/rest/v1/neo/{neo_id}/?api_key={API_KEY}'
    response = requests.request("GET", url, headers={}, data={})
    data = json.loads(response.text)
    return Asteroid(data['id'],data['name'],
                    (data['estimaed_diameter']['meters']['estimated_diameter_max']+data['estimaed_diameter']['meters']['estimated_diameter_min'])/2,
                    data['is_potentially_dangerous'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-5dc81c1f719c> in <module>
# ----> 1 @dataclass
#       2 class Asteroid():
#       3   id: str
#       4   name: str
#       5   est_diameter: float
#
# NameError: name 'dataclass' is not defined
